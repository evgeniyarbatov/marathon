# %%
import pandas as pd

# %%
df = pd.read_csv(
    '../data/marathon.csv',
    sep=',',
    header=None,
    names=[
        'Rank',
        'Time',
        'Name',
        'Country',
        'Date of Birth',
        'Place',
        'City',
        'Date',
        'Gender',
    ]
)

# %%
df['Place'] = pd.to_numeric(df['Place'], errors='coerce')

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Date of Birth'] = pd.to_datetime(df['Date of Birth'], errors='coerce')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23.04.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16.09.2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
df['Pace'] = pd.to_timedelta(df['Time']).dt.total_seconds() / (60 * 42.195)
df['Age'] = round((df['Date'] - df['Date of Birth']).dt.days / 365)

# %%
df['Time Delta'] = pd.to_timedelta(df['Time']).diff().dt.total_seconds()

# %%
df['Days Since'] = df.groupby('Name')['Date'].diff(-1)

# %%
df['Place Change'] = df.groupby('Name')['Place'].diff(-1)

# %%
df = df[df['Age'] >= 18]

# %%
df
# Out:
#       Rank     Time             Name Country Date of Birth Place  \
# 0        1  2:00:35    Kelvin Kiptum     KEN    1999-02-12     1
# 1        2  2:01:09   Eliud Kipchoge     KEN    1984-05-11     1
# 2        3  2:01:25    Kelvin Kiptum     KEN    1999-02-12     1
# 3        4  2:01:39   Eliud Kipchoge     KEN    1984-05-11     1
# 4        5  2:01:41  Kenenisa Bekele     ETH    1982-06-13     1
# ...    ...      ...              ...     ...           ...   ...
# 9401     4  2:27:33  Volha Mazurenak     BLR    1989-04-14     1
# 9402     5  2:27:37     Amane Gobena     ETH    1982-01-09     1
# 9403     6  2:28:04      Tigist Tufa     ETH    1987-01-26     2
# 9406     9  2:28:48   Lauren Kleppin     USA    1988-11-22     3
# 9407    10  2:28:59   Elfenesh Alemu     ETH    1975-10-06     2
#
#               City       Date Gender      Pace   Age  Time Delta Days Since
# 0          Chicago 2023-08-10    Men  2.857764  25.0         NaN   109 days
# ...
